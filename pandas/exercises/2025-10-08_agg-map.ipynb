# %%
import re
import warnings
import numpy as np
import pandas as pd
warnings.filterwarnings('ignore')

# %%
emp_df = pd.read_csv("data/Emp_data.csv")
emp_df.head(10)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
emp_df["First Name"].apply(lambda x:x.lower())
# Out:
# 0         lois
# 1       brenda
# 2          joe
# 3        diane
# 4     benjamin
#         ...
# 95        jose
# 96      harold
# 97      nicole
# 98     theresa
# 99       tammy
# Name: First Name, Length: 100, dtype: object

# %%
for x in emp_df.iloc[:10:2, 1]:
    emp_df.iloc[:10:2, 1] = np.nan

# %%
emp_df[emp_df['First Name'].isna()]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509        NaN       36.36             60           13.68  168251
# 2  428945        NaN       54.15             68            0.98   50155
# 4  193819        NaN       40.31             58            4.01  117642
# 6  539712        NaN       22.14             50            0.87   98189
# 8  477616        NaN       58.18             42           23.27  121587
#
#            City
# 0        Denver
# 2  Michigantown
# 4       Fremont
# 6       Atlanta
# 8       Delmita

# %% [markdown]
# # GroupBy

# %%
movies_data = pd.read_csv("data/movies_data.csv")
movies_data
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_data.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies_data[movies_data.genre == "Crime"]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_data[movies_data.genre.isin(['Crime'])]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_data.groupby('genre').get_group("Crime").head(5)
# Out:
#     star_rating                     title content_rating  genre  duration  \
# 0           9.3  The Shawshank Redemption              R  Crime       142
# 1           9.2             The Godfather              R  Crime       175
# 2           9.1    The Godfather: Part II              R  Crime       200
# 4           8.9              Pulp Fiction              R  Crime       154
# 21          8.7               City of God              R  Crime       130
#
#                                           actors_list
# 0   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1     [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4   [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 21  [u'Alexandre Rodrigues', u'Matheus Nachtergael...

# %%
movies_data[movies_data.genre.isin(['Drama', "Crime"])]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 5            8.9              12 Angry Men      NOT RATED  Drama        96
# ..           ...                       ...            ...    ...       ...
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 970          7.4               Wonder Boys              R  Drama       107
# 972          7.4            Blue Valentine          NC-17  Drama       112
# 973          7.4     The Cider House Rules          PG-13  Drama       126
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df = pd.DataFrame(np.random.randint(1,30, [6,4]), columns=["A", "B", "C", "D"])

# %%
df
# Out:
#     A   B   C   D
# 0  13  17   1  17
# 1   2   6  12  22
# 2  29  24  14  21
# 3   3  26   9   1
# 4  24  25   2  29
# 5  12  25  19  24

# %%
df.replace({28:'test'})
# Out:
#     A   B   C   D
# 0  13  17   1  17
# 1   2   6  12  22
# 2  29  24  14  21
# 3   3  26   9   1
# 4  24  25   2  29
# 5  12  25  19  24

# %%
df.replace({df.iloc[1:2:, 1].tolist()[0]: 'Updated'})
# Out:
#     A        B   C   D
# 0  13       17   1  17
# 1   2  Updated  12  22
# 2  29       24  14  21
# 3   3       26   9   1
# 4  24       25   2  29
# 5  12       25  19  24

# %%
df.iloc[1:2:, 1].tolist()[0]
# Out:
# 6

# %%
df
# Out:
#     A   B   C   D
# 0  13  17   1  17
# 1   2   6  12  22
# 2  29  24  14  21
# 3   3  26   9   1
# 4  24  25   2  29
# 5  12  25  19  24

# %%
df.replace(df.iloc[1:4:1, 1].tolist(), 'new_val')
# Out:
#          A        B   C        D
# 0       13       17   1       17
# 1        2  new_val  12       22
# 2       29  new_val  14       21
# 3        3  new_val   9        1
# 4  new_val       25   2       29
# 5       12       25  19  new_val

# %%
df.iloc[1:4:1, 1] = "new"

# %%
df
# Out:
#     A    B   C   D
# 0  13   17   1  17
# 1   2  new  12  22
# 2  29  new  14  21
# 3   3  new   9   1
# 4  24   25   2  29
# 5  12   25  19  24

# %%
df.dropna(axis=1, thresh=5)
# Out:
#     A    B   C   D
# 0  13   17   1  17
# 1   2  new  12  22
# 2  29  new  14  21
# 3   3  new   9   1
# 4  24   25   2  29
# 5  12   25  19  24

# %%
df
# Out:
#     A    B   C   D
# 0  13   17   1  17
# 1   2  new  12  22
# 2  29  new  14  21
# 3   3  new   9   1
# 4  24   25   2  29
# 5  12   25  19  24

# %%
df.rename({0:"zero"})
# Out:
#        A    B   C   D
# zero  13   17   1  17
# 1      2  new  12  22
# 2     29  new  14  21
# 3      3  new   9   1
# 4     24   25   2  29
# 5     12   25  19  24
